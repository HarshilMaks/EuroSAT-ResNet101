# %% [markdown]
# # EuroSAT-ResNet101 Exploration Notebook
#
# This notebook explores the EuroSAT dataset and sets up the environment for training a ResNet-101 model.

# %%
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('.'))))

import torch
import numpy as np
import matplotlib.pyplot as plt

# Check device availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Running cells with 'EuroSAT-ResNet101 (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/harshil/EuroSAT-ResNet101/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# Import project utilities
from src.utils.helpers import CLASS_NAMES, IMAGENET_STATS

print("EuroSAT Classes:")
for i, class_name in enumerate(CLASS_NAMES):
    print(f"  {i}: {class_name}")
    
print(f"\nImageNet Normalization Stats:")
print(f"  Mean: {IMAGENET_STATS['mean']}")
print(f"  Std: {IMAGENET_STATS['std']}")

# %%
# Check data directory structure
import os

data_dirs = ["data/raw", "data/processed"]

for data_dir in data_dirs:
    if os.path.exists(data_dir):
        print(f"\n✓ {data_dir} exists")
        try:
            files = os.listdir(data_dir)
            print(f"  Contents: {files}")
        except Exception as e:
            print(f"  Error listing contents: {e}")
    else:
        print(f"\n✗ {data_dir} does not exist")

# %%
# Project structure overview
print("Project Structure:")
print("src/")
print("├── data/")
print("│   ├── dataset.py       # EuroSAT dataset loading")
print("│   └── preprocess.py    # Data preprocessing pipeline")
print("├── models/")
print("│   └── model.py         # ResNet-101 implementation")
print("├── training/")
print("│   └── train.py         # Training pipeline")
print("├── evaluation/")
print("│   ├── eval.py          # Model evaluation")
print("│   └── visualize.py     # Visualization & confusion matrix")
print("├── utils/")
print("│   └── helpers.py       # Utilities & constants")
print("└── main.py              # Entry point for testing")

# %%
# Try importing key modules
try:
    from src.models.model import get_resnet101, get_model_info
    print("✓ Successfully imported ResNet-101 model")
except Exception as e:
    print(f"✗ Error importing model: {e}")

try:
    from src.data.preprocess import EuroSATDataset, GetDataLoaders
    print("✓ Successfully imported data preprocessing modules")
except Exception as e:
    print(f"✗ Error importing data modules: {e}")

try:
    from src.utils.helpers import CLASS_NAMES, load_processed_data
    print("✓ Successfully imported utility functions")
except Exception as e:
    print(f"✗ Error importing utils: {e}")

# %%
# Model initialization test
try:
    model = get_resnet101(num_classes=10, freeze_backbone=True)
    print("✓ ResNet-101 model created successfully")
    
    # Test forward pass with dummy input
    dummy_input = torch.randn(1, 3, 224, 224)
    with torch.no_grad():
        output = model.to(device)(dummy_input.to(device))
    print(f"  Input shape: {dummy_input.shape}")
    print(f"  Output shape: {output.shape}")
except Exception as e:
    print(f"✗ Error: {e}")
